# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../DistillBert/Output/distilbert_sentiment_scores.csv")

print(df.head())
print(df.columns)
# Out:
#                                            post_text sentiment_label  \
# 0  Does Strattera work for anyone?. psychiatrist ...        NEGATIVE
# 1  How can I become a better student and stop fee...        NEGATIVE
# 2  able to read social cues fine but not know how...        NEGATIVE
# 3  Focussing and Concentrating on dull tasks is a...        NEGATIVE
# 4  random - label maker recommendations. random r...        NEGATIVE
#
#    sentiment_score
# 0         0.995250
# 1         0.999403
# 2         0.954388
# 3         0.999135
# 4         0.984967
# Index(['post_text', 'sentiment_label', 'sentiment_score'], dtype='object')

# %%
df_plot = df.rename(columns={
    'post_text': 'Post Text',
    'sentiment_label': 'Sentiment Label',
    'sentiment_score': 'Sentiment Score'
})

# %%
plt.figure(figsize=(8, 5))
df_plot['Sentiment Label'].value_counts().plot(kind='bar')
plt.title("Distribution of DistilBERT Sentiment Labels")
plt.xlabel("Sentiment Label")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df_plot['Sentiment Score'], bins=30)
plt.title("Histogram of DistilBERT Sentiment Scores")
plt.xlabel("Sentiment Score")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df_plot['Sentiment Score'])
plt.title("Boxplot of Sentiment Score")
plt.ylabel("Sentiment Score")
plt.tight_layout()
plt.show()
